# %% [markdown]
# # Case Study on Correlation and Regression

# %%
# A textile company regularly spent money on five advertising companies for their adds.

# %%
# Read the Add_sales_data_2018 dataset to the python environment

# %%
# Importing the required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the CSV file into a pandas dataframe.

data= pd.read_csv(r'C:\ict\Assignments\4 Case study 3\Add_sales_data_2018.csv')
data

# %%
# Removing the 'date' column.

data1=data.drop(['Date'],axis=1)
data1

# %% [markdown]
# # 1. First of all, check whether there is any relationship between the amount spent for advertising through five different companies and profit generated.

# %%
# To find the correlation between the variables

corrmatrix = data1.corr()
plt.subplots(figsize=(10,8))
sns.heatmap(corrmatrix,vmin=0.98,vmax=1,annot=True,linewidth=0.2,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
 INSIGHTS

# Each square shows the correlation between the variables on each axis.
# Here the correlation coefficient is greater than 0(+0.98 to +1),so positive correlation :
#                   it signifies that both variables move in the same direction.
# When it is +1: 
#        it signifies that the two variables being compared have a perfect positive relationship. 

# The value close to 1 :
#       the correlation is the more positively correlated they are;
#       that is as one increases so does the other and 
#       the closer to 1 the stronger this relationship .
# The diagonals are all dark color:
#      because are correlating each variable to itself (so it's a perfect correlation).

# The  money spent by textile company on five advertising companies for their adds:
#                  are having high positive correlation with the profit.
# The money spent for advertising company(Add 2) has :
#                 highest positive correlation with the profit.
#The  money spent by textile company on advertising companies Add1,Add3,Add4 and Add5:
#                 are having positive corrilation of 0.99
# Add4 and Add5 are highly correlated to each other.

# %% [markdown]
# # 2. Build a regression model to predict the profit from the given data and comment your findings on it.

# %%
# splitting the data set into dependent and independent variables
# dependent variable is store to y and independent variable to x
# dependent variable is the profit and all other features are independent variables

# %%
y = data1['Profit(in Thousands)']
x = data1.drop(['Profit(in Thousands)'],axis=1)

# %%
x.shape
# Out:
# (205, 5)

# %%
# split the dataset into train and test set
# training and testing set is available in Sklearn library

# %%
#importing train_test_split from the scikit-learn library

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.25)

# %%
# now we can make a linear regression model
# for that we are importing the model from sklearn library

from sklearn import linear_model

# %%
lr = linear_model.LinearRegression()

# %%
# next we are fitting the instance we are created to our training data
# and creating the linear regression model and store it into another variable

model = lr.fit(x_train,y_train)

# %%
# now our model is ready to predict the o/p
# and now we will predict the o/p for x_test

predictions = model.predict(x_test)

# %%
print(y_test)
# Out:
# 15     4152.066
# 9      4446.441
# 100    5131.898
# 132    4907.560
# 68     5004.282
# 95     4623.793
# 159    5384.175
# 162    5328.025
# 147    5175.051
# 182    5956.323
# 191    5780.799
# 164    4997.719
# 65     5075.858
# 175    5784.540
# 73     4936.120
# 152    5065.652
# 18     4190.965
# 82     5034.726
# 86     5015.536
# 143    5134.657
# 60     5145.131
# 101    5421.940
# 98     4569.293
# 30     4598.292
# 25     4436.321
# 16     4175.677
# 168    5616.791
# 195    5667.250
# 97     4648.834
# 194    5717.838
# 67     5001.615
# 120    5182.368
# 154    5017.503
# 202    5545.013
# 79     5013.207
# 69     5030.451
# 145    5108.626
# 55     4760.877
# 45     4606.340
# 84     4925.861
# 146    5250.788
# 66     5038.222
# 111    5491.792
# 153    5019.997
# 96     4647.356
# 38     4486.380
# 24     4435.174
# 139    5300.437
# 112    5425.190
# 29     4482.183
# 19     4193.095
# 178    6062.457
# Name: Profit(in Thousands), dtype: float64

# %%
# now we will check what is the predicted value

print(predictions)
# Out:
# [4152.066 4446.441 5131.898 4907.56  5004.282 4623.793 5384.175 5328.025
#  5175.051 5956.323 5780.799 4997.719 5075.858 5784.54  4936.12  5065.652
#  4190.965 5034.726 5015.536 5134.657 5145.131 5421.94  4569.293 4598.292
#  4436.321 4175.677 5616.791 5667.25  4648.834 5717.838 5001.615 5182.368
#  5017.503 5545.013 5013.207 5030.451 5108.626 4760.877 4606.34  4925.861
#  5250.788 5038.222 5491.792 5019.997 4647.356 4486.38  4435.174 5300.437
#  5425.19  4482.183 4193.095 6062.457]

# %%
# by comparing these values the mean squared error can be found of
# for that we will import mean squared error from the matrix class of the sklearn library
# and print it

from sklearn.metrics import mean_squared_error

# %%
print('MSE is:',mean_squared_error(y_test,predictions))
# Out:
# MSE is: 5.408488620539027e-25

# %%
# Calculating the R squared value
# importing r2_score from sklearn.metrics
from sklearn.metrics import r2_score
r2_score_value = r2_score(y_test, predictions)
r2_score_value
# Out:
# 1.0

# %%
INSIGHTS
# Here Mean Squared Error is low and R squared value of 1 proves that the model is a Good Model.

# %% [markdown]
# # 3. Predict the profit generated by the company, if they wish to spend the following amount for advertisement.
# Add1(in Thousands)=290 Add2(in Thousands)=312 Add3(in Thousands)=309 Add4(in Thousands)=298 Add5(in Thousands)=320

# %%
x_value=[[290,312,309,298,320]]

# %%
predictions_new = model.predict(x_value)

# %%
print(predictions_new)
# Out:
# [5820.06]

# %%
INSIGHTS
# The Predicted profit generated by the company by spending the amount for advertisement is 5820.06
