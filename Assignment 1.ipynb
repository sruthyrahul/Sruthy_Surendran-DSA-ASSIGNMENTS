# %% [markdown]
# # Assignment on Python for Data Science

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Read the dataset to python environment

# %%
iris = pd.read_excel(r'C:\ict\Assignments\1\iris.xls')

# %%
iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2. Display the columns in the dataset.

# %%
iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # 3. Calculate the mean of each column of the dataset

# %%
iris.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4. Check for the null values present in the dataset.

# %%
iris.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
iris.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %% [markdown]
# # Histogram of Sepal Length "SL"

# %%
plt.figure()
plt.hist(iris['SL'],color='violet',rwidth=0.8)
plt.title('Visualisation of SL',color='green',fontsize=16)
plt.xlabel('SepalLength',color='blue')
plt.ylabel('Frequency',color='blue')
plt.xticks()
plt.yticks()
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Histogram of classification

# %%
plt.hist(iris['Classification'])
plt.grid()
plt.show()
print('The number of species in the iris are equal')
# Out:
# The number of species in the iris are equal

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x='Classification',y='PL', data=iris)
plt.show()

# %%
# Observation
# Clearly the mean/ median values are being shown by the plot for petal lenth
# Iris-Setosa is having smaller petal length and less distributed
# Iris-Versicolor is distributed in a average manner and average petal length
# Iris-Virginica is highly distributed with large no .of values and petal lenth

# %% [markdown]
# # Violinplot

# %%
sns.violinplot(x="Classification", y="PL", data=iris, size=5)
plt.show()

# %%
#Observation
#Setosa is having less distribution and density.
#Versicolor is distributed in a average manner.
#Virginica is highly distributed with large no .of values.

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(10,12))
sns.heatmap(iris.corr(),annot=True)
plt.plot()
# Out:
# []

# %%
# Observations.
# Sepal Length and Sepal Width features are slightly correlated with each other.

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(iris,hue="Classification",height=4)

# %%
# Observations.
# High co relation between PL and PW columns.
# Iris-Setosa has both low PL and PW.
# SW for Iris-setosa is high and SL is low.
# Iris-Versicolor has both average PL and PW.
# Iris-Versicolor have average values for sepal dimensions.
# Iris-Virginica has both high PL and PW.
# Iris-Virginica has small SW but large SL.
